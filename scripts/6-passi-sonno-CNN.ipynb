# %%
from scripts.shared_utilities import *
# Out:
# 2024-05-29 21:25:48.256241: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-29 21:25:48.259254: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-29 21:25:48.301417: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-29 21:25:49.123717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = KerasCNNModel(path=Path("../models/modello-passi-sonno-CNN.keras"))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 48, 20)         │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 48, 20)         │           820 │
# ...

# %%
data = DateStepSleepData()
data.get_dataset().head()
# Out:
#                                        uuid      date    steps  sleep_score  \
# 0  1003e58667235e01b49008155604980b3900b00e  0.332418  3049.04          NaN
# 1  1003e58667235e01b49008155604980b3900b00e  0.335165  4309.81     0.547576
# 2  1003e58667235e01b49008155604980b3900b00e  0.337912   255.11          NaN
# 3  1003e58667235e01b49008155604980b3900b00e  0.340659  5118.07          NaN
# 4  1003e58667235e01b49008155604980b3900b00e  0.343407  2228.88     0.415384
#
#     n_steps  n_sleep_score  n_steps_all  n_sleep_score_all
# 0 -0.466397            NaN    -0.866270                NaN
# 1 -0.185709      -0.571941    -0.600012          -0.367737
# 2 -1.088416            NaN    -1.456310                NaN
# 3 -0.005764            NaN    -0.429319                NaN
# 4 -0.648991      -1.367748    -1.039477          -1.259176

# %%
utils = Utilities(model, data)

# %%
utils.train_model()
# Out:
# Epoch 1/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.8508 - r2_score: 0.0011 - val_loss: 0.9039 - val_r2_score: 0.0017
# Epoch 2/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8291 - r2_score: 0.0041 - val_loss: 0.9057 - val_r2_score: -4.0269e-04
# Epoch 3/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8359 - r2_score: 0.0094 - val_loss: 0.8986 - val_r2_score: 0.0075
# Epoch 4/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.8272 - r2_score: 0.0246 - val_loss: 0.9177 - val_r2_score: -0.0136
# Epoch 5/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7948 - r2_score: 0.0409 - val_loss: 0.9214 - val_r2_score: -0.0177
# Epoch 6/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7731 - r2_score: 0.0621 - val_loss: 0.9374 - val_r2_score: -0.0354
# Epoch 7/20
# 1001/1001 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.7648 - r2_score: 0.0849 - val_loss: 0.9488 - val_r2_score: -0.0480
# Epoch 8/20
# ...

# %%
utils.evaluate_model()
# Out:
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8853 - r2_score: -0.0473
# [0.9317665696144104, -0.04630899429321289]

# %%
model.save()

# %%
DateSleepStepPredictionVisualization(model, data).visualize()
