# %%
import pandas as pd
import keras
import matplotlib.pyplot as plt
from scripts.config import window,test_ratio

# %%
df = pd.read_csv("../data/scalati.csv.gz")[-10000:]  # I dati sono tanti, non ho una CUDA quindi non posso usarli tutti
df.dropna(inplace=True)
df.head(200)
# Out:
#                                              uuid      date     steps  \
# 1291394  fe2c5a3fee51af4f62027125aaa6c0b74247b406  0.167582  13867.35
# 1291395  fe2c5a3fee51af4f62027125aaa6c0b74247b406  0.170330   6848.24
# 1291396  fe2c5a3fee51af4f62027125aaa6c0b74247b406  0.173077  15204.16
# 1291397  fe2c5a3fee51af4f62027125aaa6c0b74247b406  0.175824  19235.33
# 1291398  fe2c5a3fee51af4f62027125aaa6c0b74247b406  0.178571   9433.45
# ...                                           ...       ...       ...
# 1291589  fe3ac99c5ecac9209440d5954e96fd2265fedbba  0.365385   5530.30
# 1291590  fe3ac99c5ecac9209440d5954e96fd2265fedbba  0.368132   7133.17
# 1291591  fe3ac99c5ecac9209440d5954e96fd2265fedbba  0.370879   9117.52
# 1291592  fe3ac99c5ecac9209440d5954e96fd2265fedbba  0.373626   5043.00
# 1291593  fe3ac99c5ecac9209440d5954e96fd2265fedbba  0.376374   3837.50
#
#          sleep_score   n_steps  n_sleep_score
# 1291394     0.723122  0.588031       1.124486
# 1291395     0.716472 -0.999667       1.073170
# 1291396     0.666149  0.890413       0.684798
# 1291397     0.292907  1.802250      -2.195733
# 1291398     0.555619 -0.414902      -0.168232
# ...              ...       ...            ...
# 1291589     0.565940 -0.605714       0.018786
# 1291590     0.564440 -0.151352       0.005221
# 1291591     0.662308  0.411147       0.890264
# 1291592     0.389076 -0.743848      -1.580635
# 1291593     0.619467 -1.085568       0.502838
#
# [200 rows x 6 columns]

# %%
import numpy as np

xtrain = []
ytrain = []
xtest=[]
ytest=[]
for uuid, group in df.groupby('uuid')[["date","n_steps","n_sleep_score"]]:
    split=int(len(group)*(1-test_ratio))
    if split<window:
        continue
        
    inputs = np.array(group[["date","n_steps"]].values)
    output = np.array(group["n_sleep_score"].values)


    for i in range (window,split):
        xtrain.append(inputs[i-window:i]) # Una finestra di <window> osservazioni sui passi
        ytrain.append(output[i]) # La qualità del sonno alla fine della finestra

    for i in range (split,len(group)):
        xtest.append(inputs[i-window:i])
        ytest.append(output[i])

xtrain=np.array(xtrain).reshape(-1,window,2)
ytrain=np.array(ytrain).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,window,2)
ytest=np.array(ytest).reshape(-1,1)

# %%
inputs = keras.Input(shape=(window,2))
old = inputs
for rate in (1, 2, 4, 8) * 2:
    old = keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate)(old)
flatten = keras.layers.Flatten()(old)
output = keras.layers.Dense(1)(flatten)

model=keras.Model(inputs=inputs, outputs=output)
model.compile(loss=keras.losses.MeanSquaredError(), metrics=[keras.metrics.R2Score()])
model.summary()

#L'ho definita secondo l'API funzionale di Keras, in modo da poter estrarre le attivazioni dei layer intermedi con facilità
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 48, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 48, 20)         │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_17 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_18 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_19 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_22 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_23 (Conv1D)              │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 960)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           961 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,801 (26.57 KB)
#  Trainable params: 6,801 (26.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.src.callbacks import EarlyStopping,ModelCheckpoint

history = model.fit(xtrain, ytrain, epochs=20, verbose=1, validation_split=.2,
                    callbacks=[EarlyStopping(monitor='val_r2_score', patience=5),
                               ModelCheckpoint(filepath='best_model.keras', monitor='val_r2_score',
                                               save_best_only=True)])
# Out:
# Epoch 1/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.9708 - r2_score: -0.0027 - val_loss: 0.9849 - val_r2_score: -0.0014
# Epoch 2/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9994 - r2_score: -0.0010 - val_loss: 0.9856 - val_r2_score: -0.0021
# Epoch 3/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9706 - r2_score: 4.6127e-04 - val_loss: 0.9925 - val_r2_score: -0.0091
# Epoch 4/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9854 - r2_score: 0.0085 - val_loss: 0.9867 - val_r2_score: -0.0032
# Epoch 5/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9818 - r2_score: 0.0163 - val_loss: 0.9895 - val_r2_score: -0.0061
# Epoch 6/20
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9568 - r2_score: 0.0166 - val_loss: 1.0136 - val_r2_score: -0.0306

# %%
plt.plot(history.history['loss'], label='Original loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
model.evaluate(xtest, ytest)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0938 - r2_score: -0.0402
# [1.0808652639389038, -0.03650689125061035]

# %%
model.save("../models/modello-passi-sonno.keras")

# %%
df=pd.read_csv("../data/scalati.csv.gz")[11091:139082]

# %%
for uuid,group in df.groupby('uuid'):
    if len(group)<2*window:
        continue
    common = group[["date","n_steps"]].values
    actual = group["n_sleep_score"].values
    data=[]
    for i in range(window,len(common)):
        data.append(common[i - window:i])
    data=np.array(data)
    pred = model.predict_on_batch(data)
    pred=np.array(pred)
    plt.title("prediction for user: "+uuid)
    plt.plot(group["date"][window:2*window],actual[window:2*window],label='Actual')
    plt.plot(group["date"][window:2*window],pred[:window],label='Predicted')
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 8
#       6 pred=[]
#       7 for i in range(window,len(common)):
# ----> 8     pred.extend(model.predict(np.array([common[i-window:i].reshape(48,2)]),verbose=0))
#       9 pred=np.array(pred)
#      10 plt.title("prediction for user: "+uuid)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:453, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     451 # Container that configures and calls callbacks.
#     452 if not isinstance(callbacks, callbacks_module.CallbackList):
# --> 453     callbacks = callbacks_module.CallbackList(
#     454         callbacks,
#     455         add_history=True,
#     456         add_progbar=verbose != 0,
#     457         verbose=verbose,
#     458         epochs=1,
#     459         steps=epoch_iterator.num_batches,
#     460         model=self,
#     461     )
#     463 def append_to_outputs(batch_outputs, outputs):
#     464     if outputs is None:
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/callbacks/callback_list.py:40, in CallbackList.__init__(self, callbacks, add_history, add_progbar, model, **params)
#      37 self._add_default_callbacks(add_history, add_progbar)
#      39 if model:
# ---> 40     self.set_model(model)
#      41 if params:
#      42     self.set_params(params)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/callbacks/callback_list.py:74, in CallbackList.set_model(self, model)
#      72 super().set_model(model)
#      73 if self._history:
# ---> 74     model.history = self._history
#      75 for callback in self.callbacks:
#      76     callback.set_model(model)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/layers/layer.py:1357, in Layer.__setattr__(self, name, value)
#    1355 elif name != "_tracker":
#    1356     self._initialize_tracker()
# -> 1357 return super().__setattr__(name, value)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trackable.py:15, in KerasAutoTrackable.__setattr__(self, name, value)
#       6 class KerasAutoTrackable(tf.__internal__.tracking.AutoTrackable):
#       7     """Manages dependencies on other objects with Keras tracking.
#       8
#       9     Similar to TF AutoTrackable, but disabling tracking is based
#    (...)
#      12     This serves as an interface between Keras tracking and TF tracking.
#      13     """
# ---> 15     def __setattr__(self, name, value):
#      16         """Support self.foo = trackable syntax."""
#      17         try:
#
# KeyboardInterrupt:

# %%
for uuid,group in df.groupby('uuid'):
    if len(group)<32:
        continue
    group=group[-32:]
    steps = group.n_steps.values
    sleep = group.n_sleep_score.values
    dates = group.date.values
    plt.title("prediction for user: "+uuid)
    plt.plot(dates,steps,label='Actual')
    plt.plot(dates,sleep,label='Predicted')
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/PIL/ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 11
#       9 plt.plot(dates,steps,label='Actual')
#      10 plt.plot(dates,sleep,label='Predicted')
# ---> 11 plt.show()
#      12 plt.close()
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py:607, in show(*args, **kwargs)
#     563 """
#     564 Display all open figures.
#     565
#    (...)
#     604 explicitly there.
#     605 """
#     606 _warn_if_gui_out_of_main_thread()
# --> 607 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/PIL/Image.py:2459, in Image.save(self, fp, format, **params)
#    2456         fp = builtins.open(filename, "w+b")
#    2458 try:
# -> 2459     save_handler(self, fp, filename)
#    2460 except Exception:
#    2461     if open_fp:
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/PIL/PngImagePlugin.py:1412, in _save(im, fp, filename, chunk, save_all)
#    1408     im = _write_multiple_frames(
#    1409         im, fp, chunk, rawmode, default_image, append_images
#    1410     )
#    1411 if im:
# -> 1412     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1414 if info:
#    1415     for info_chunk in info.chunks:
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/PIL/ImageFile.py:540, in _save(im, fp, tile, bufsize)
#     538     _encode_tile(im, fp, tile, bufsize, fh)
#     539 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 540     _encode_tile(im, fp, tile, bufsize, None, exc)
#     541 if hasattr(fp, "flush"):
#     542     fp.flush()
#
# File ~/PycharmProjects/ML-Project/.venv/lib/python3.11/site-packages/PIL/ImageFile.py:559, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     556 if exc:
#     557     # compress to Python file-compatible object
#     558     while True:
# --> 559         errcode, data = encoder.encode(bufsize)[1:]
#     560         fp.write(data)
#     561         if errcode:
#
# KeyboardInterrupt:
