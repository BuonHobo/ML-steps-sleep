# %% [markdown]
# Noto che la remduration manca praticamente sempre, mentre il resto dei dati sul sonno sono presenti sempre tutti insieme. Trovo un modo per calcolare il punteggio che faccia uso di questi dati.

# %%
import pandas as pd

# %%
steps = pd.read_csv("../data/dati.csv.gz")[
    ["uuid", "date", "steps", 'sleepduration', 'lightduration', 'deepduration']].dropna() # Il dataset qui è abbastanza denso, per ora può andare bene eliminare le righe con valori mancanti

# %%
def sleep_score(x):
    optimal_light_ratio = .5
    optimal_deep_ratio = .25
    
    # Penalità sul light sleep X Penalità sul deep sleep X Penalità sulla durata del sonno
    x["sleep_score"] = (1 - abs(x["lightduration"] / x["sleepduration"] - optimal_light_ratio)) * (1 - abs(x["deepduration"] / x["sleepduration"] - optimal_deep_ratio)) * (1 - abs(x["sleepduration"] / x["sleepduration"].mean() - 1))
    return x


steps = steps.groupby("uuid").apply(sleep_score,include_groups=False)
steps.sample(100)
# Out:
#                                                         date     steps  \
# uuid
# e476c9b1eb734f61a04e1cbe5ef0c8b7f42c6eb9 1897841  2017-03-20   3261.45
# 10be16946a1bcc87c089e9aa61ce534f72729ac7 8971     2016-10-02   2794.38
# d1295627bc91e7094383311229e19638ca91fe9b 1739021  2016-12-09  15626.94
# d4e2580f941a71e6b5ebfcd958995876bfb9a808 1770748  2016-04-14   6246.36
# 1c5811e168c3e4389194752ca956e94f2f125169 124176   2016-04-19   6078.64
# ...                                                      ...       ...
# 6cb065b45f35620dce4d75811251ac6ce3debec8 842911   2016-05-07   2237.90
# 52985926f409e12233f0286e2f1c348fb166edcc 613782   2017-02-19   3464.51
# 47a17e9b379476ea1091efe04beb45fcb5a1337e 514032   2016-08-17  10394.98
# f9dd0a3a9ad733378d7e2ddd94301445729b75b7 2097775  2016-06-11   5153.47
# df7e24896e360740758815e54603bbe2c2f5abd4 1853141  2016-08-07   7295.67
#
#                                                   sleepduration  \
# uuid
# e476c9b1eb734f61a04e1cbe5ef0c8b7f42c6eb9 1897841           4.87
# 10be16946a1bcc87c089e9aa61ce534f72729ac7 8971              9.16
# d1295627bc91e7094383311229e19638ca91fe9b 1739021           7.37
# d4e2580f941a71e6b5ebfcd958995876bfb9a808 1770748           4.79
# 1c5811e168c3e4389194752ca956e94f2f125169 124176            8.21
# ...                                                         ...
# 6cb065b45f35620dce4d75811251ac6ce3debec8 842911            8.96
# 52985926f409e12233f0286e2f1c348fb166edcc 613782            6.78
# 47a17e9b379476ea1091efe04beb45fcb5a1337e 514032            7.57
# f9dd0a3a9ad733378d7e2ddd94301445729b75b7 2097775          10.12
# df7e24896e360740758815e54603bbe2c2f5abd4 1853141           4.83
#
#                                                   lightduration  deepduration  \
# uuid
# e476c9b1eb734f61a04e1cbe5ef0c8b7f42c6eb9 1897841           2.87          1.98
# 10be16946a1bcc87c089e9aa61ce534f72729ac7 8971              4.88          4.28
# d1295627bc91e7094383311229e19638ca91fe9b 1739021           4.83          2.56
# d4e2580f941a71e6b5ebfcd958995876bfb9a808 1770748           1.63          3.13
# 1c5811e168c3e4389194752ca956e94f2f125169 124176            3.61          4.62
# ...                                                         ...           ...
# 6cb065b45f35620dce4d75811251ac6ce3debec8 842911            3.70          5.29
# 52985926f409e12233f0286e2f1c348fb166edcc 613782            3.58          3.15
# 47a17e9b379476ea1091efe04beb45fcb5a1337e 514032            3.45          4.14
# f9dd0a3a9ad733378d7e2ddd94301445729b75b7 2097775           6.59          3.58
# df7e24896e360740758815e54603bbe2c2f5abd4 1853141           2.14          2.71
#
#                                                   sleep_score
# uuid
# e476c9b1eb734f61a04e1cbe5ef0c8b7f42c6eb9 1897841     0.488394
# 10be16946a1bcc87c089e9aa61ce534f72729ac7 8971        0.658284
# d1295627bc91e7094383311229e19638ca91fe9b 1739021     0.734343
# d4e2580f941a71e6b5ebfcd958995876bfb9a808 1770748     0.342657
# 1c5811e168c3e4389194752ca956e94f2f125169 124176      0.484469
# ...                                                       ...
# 6cb065b45f35620dce4d75811251ac6ce3debec8 842911      0.572238
# 52985926f409e12233f0286e2f1c348fb166edcc 613782      0.755144
# 47a17e9b379476ea1091efe04beb45fcb5a1337e 514032      0.628684
# f9dd0a3a9ad733378d7e2ddd94301445729b75b7 2097775     0.539650
# df7e24896e360740758815e54603bbe2c2f5abd4 1853141     0.390125
#
# [100 rows x 6 columns]

# %%
steps = steps.rename_axis(["uuid","id"]).reset_index().drop(columns=["id"]) # Per un csv più pulito, infatti il groupby aggiunge una colonna che non voglio
steps.head()
# Out:
#                                        uuid        date    steps  \
# 0  1003e58667235e01b49008155604980b3900b00e  2016-08-01  4309.81
# 1  1003e58667235e01b49008155604980b3900b00e  2016-08-04  2228.88
# 2  1003e58667235e01b49008155604980b3900b00e  2016-08-10  7340.69
# 3  1003e58667235e01b49008155604980b3900b00e  2016-08-15  8644.73
# 4  1003e58667235e01b49008155604980b3900b00e  2016-09-01  1643.17
#
#    sleepduration  lightduration  deepduration  sleep_score
# 0          11.31           7.38          3.99     0.547576
# 1          12.90           7.91          4.94     0.415384
# 2           9.15           5.61          3.58     0.734624
# 3           7.87           4.63          3.19     0.685811
# 4           3.05           1.04          2.03     0.169635

# %% [markdown]
# Non ho più bisogno degli altri dati, mi tengo solo quelli sui passi e sulla qualità del sonno.

# %%
steps[["uuid","date","steps","sleep_score"]].to_csv("../data/valutati.csv.gz",index=False)
