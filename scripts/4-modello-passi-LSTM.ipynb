# %%
from scripts.shared_utilities import *

# %%
model = KerasLSTMModel(path=Path("../models/modello-passi-LSTM.keras"))
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 48, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 30)             │         3,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,991 (15.59 KB)
#  Trainable params: 3,991 (15.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
data = DateStepData()
data.get_dataset().head()
# Out:
#                                        uuid      date    steps  sleep_score  \
# 0  1003e58667235e01b49008155604980b3900b00e  0.332418  3049.04          NaN
# 1  1003e58667235e01b49008155604980b3900b00e  0.335165  4309.81     0.547576
# 2  1003e58667235e01b49008155604980b3900b00e  0.337912   255.11          NaN
# 3  1003e58667235e01b49008155604980b3900b00e  0.340659  5118.07          NaN
# 4  1003e58667235e01b49008155604980b3900b00e  0.343407  2228.88     0.415384
#
#     n_steps  n_sleep_score  n_steps_all  n_sleep_score_all
# 0 -0.466397            NaN    -0.866270                NaN
# 1 -0.185709      -0.571941    -0.600012          -0.367737
# 2 -1.088416            NaN    -1.456310                NaN
# 3 -0.005764            NaN    -0.429319                NaN
# 4 -0.648991      -1.367748    -1.039477          -1.259176

# %%
utils = Utilities(model, data)

# %%
utils.train_model()
# Out:
# Epoch 1/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 0.6700 - r2_score: 0.3481 - val_loss: 0.6039 - val_r2_score: 0.3333
# Epoch 2/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6243 - r2_score: 0.3761 - val_loss: 0.6122 - val_r2_score: 0.3242
# Epoch 3/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6299 - r2_score: 0.3695 - val_loss: 0.6056 - val_r2_score: 0.3314
# Epoch 4/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6203 - r2_score: 0.3818 - val_loss: 0.5974 - val_r2_score: 0.3405
# Epoch 5/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6322 - r2_score: 0.3763 - val_loss: 0.5951 - val_r2_score: 0.3430
# Epoch 6/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6332 - r2_score: 0.3775 - val_loss: 0.5968 - val_r2_score: 0.3411
# Epoch 7/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6165 - r2_score: 0.3803 - val_loss: 0.5874 - val_r2_score: 0.3515
# Epoch 8/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6295 - r2_score: 0.3822 - val_loss: 0.5870 - val_r2_score: 0.3519
# Epoch 9/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6173 - r2_score: 0.3846 - val_loss: 0.5871 - val_r2_score: 0.3518
# Epoch 10/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6204 - r2_score: 0.3787 - val_loss: 0.5867 - val_r2_score: 0.3523
# Epoch 11/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6127 - r2_score: 0.3850 - val_loss: 0.5834 - val_r2_score: 0.3560
# Epoch 12/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6099 - r2_score: 0.3935 - val_loss: 0.5873 - val_r2_score: 0.3516
# Epoch 13/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 0.6190 - r2_score: 0.3872 - val_loss: 0.5868 - val_r2_score: 0.3521
# Epoch 14/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6183 - r2_score: 0.3928 - val_loss: 0.5826 - val_r2_score: 0.3567
# Epoch 15/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6170 - r2_score: 0.3930 - val_loss: 0.5836 - val_r2_score: 0.3557
# Epoch 16/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6155 - r2_score: 0.3928 - val_loss: 0.5859 - val_r2_score: 0.3532
# Epoch 17/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6087 - r2_score: 0.3983 - val_loss: 0.5847 - val_r2_score: 0.3545
# Epoch 18/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6158 - r2_score: 0.3881 - val_loss: 0.5813 - val_r2_score: 0.3582
# Epoch 19/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6068 - r2_score: 0.3970 - val_loss: 0.5835 - val_r2_score: 0.3558
# Epoch 20/20
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.6011 - r2_score: 0.3974 - val_loss: 0.5817 - val_r2_score: 0.3578

# %%
utils.evaluate_model()
# Out:
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6300 - r2_score: 0.4241
# [0.6094791889190674, 0.402498722076416]

# %%
model.save()

# %%
DateStepPredictionForecastVisualization(model, data, 5).visualize()
