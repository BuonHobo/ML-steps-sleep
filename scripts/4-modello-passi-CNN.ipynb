# %%
from scripts.shared_utilities import *

# %%
model = KerasCNNModel(path=Path("../models/modello-passi-CNN.keras"))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 48, 20)         │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 48, 20)         │           820 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 48, 20)         │           820 │
# ...

# %%
data = DateStepData()
data.get_dataset().head()
# Out:
#                                        uuid      date    steps  sleep_score  \
# 0  1003e58667235e01b49008155604980b3900b00e  0.332418  3049.04          NaN
# 1  1003e58667235e01b49008155604980b3900b00e  0.335165  4309.81     0.547576
# 2  1003e58667235e01b49008155604980b3900b00e  0.337912   255.11          NaN
# 3  1003e58667235e01b49008155604980b3900b00e  0.340659  5118.07          NaN
# 4  1003e58667235e01b49008155604980b3900b00e  0.343407  2228.88     0.415384
#
#     n_steps  n_sleep_score  n_steps_all  n_sleep_score_all
# 0 -0.466397            NaN    -0.866270                NaN
# 1 -0.185709      -0.571941    -0.600012          -0.367737
# 2 -1.088416            NaN    -1.456310                NaN
# 3 -0.005764            NaN    -0.429319                NaN
# 4 -0.648991      -1.367748    -1.039477          -1.259176

# %%
utils = Utilities(model, data)

# %%
utils.train_model()
# Out:
# Epoch 1/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.9497 - r2_score: 0.2170 - val_loss: 0.6144 - val_r2_score: 0.6226
# Epoch 2/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8615 - r2_score: 0.3044 - val_loss: 0.6236 - val_r2_score: 0.6169
# Epoch 3/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8768 - r2_score: 0.3428 - val_loss: 0.5894 - val_r2_score: 0.6379
# Epoch 4/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8275 - r2_score: 0.3429 - val_loss: 0.6451 - val_r2_score: 0.6037
# Epoch 5/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8016 - r2_score: 0.3593 - val_loss: 0.6177 - val_r2_score: 0.6205
# Epoch 6/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8537 - r2_score: 0.3576 - val_loss: 0.6291 - val_r2_score: 0.6135
# Epoch 7/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7339 - r2_score: 0.3914 - val_loss: 0.5995 - val_r2_score: 0.6317
# Epoch 8/20
# ...

# %%
utils.evaluate_model()
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7645 - r2_score: 0.3028
# [0.7251924276351929, 0.4518061876296997]

# %%
model.save()

# %%
DateStepPredictionForecastVisualization(model, data, 5).visualize()
